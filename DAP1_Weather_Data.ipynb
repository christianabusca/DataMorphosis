# %% [markdown]
# <a href="https://colab.research.google.com/github/christianabusca/daanaprojekta/blob/main/DAP1_Weather_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTING LIBRARIES

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# IMPORTING THE DATA, particularly the file.csv file.

data = pd.read_csv('sample_data/file.csv')
data.head() # SHOWS THE FIRST 5 ROWS IN THE FILE
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape # SHOWS THE NUMBER OF ROWS AND COLUMNS IN THE FILE, (ROWS, COLUMNS)
# Out:
# (8784, 8)

# %%
data.index # SHOWS THE INDEX OF THE FILE
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns # SHOWS THE COLUMNS IN THE FILE
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes # SHOWS THE DATA TYPES OF THE COLUMNS IN THE FILE
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique() # SHOWS THE UNIQUE VALUES IN THE FILE
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Weather'].nunique() # SHOWS THE NUMBER OF UNIQUE VALUES IN THE FILE
# Out:
# 50

# %%
data.count() # SHOWS THE NUMBER OF NON-NULL VALUES IN THE FILE
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data['Weather'].value_counts() # SHOWS THE NUMBER OF TIMES EACH VALUE APPEARS IN THE FILE
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data.info() # SHOWS THE INFORMATION OF THE FILE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# PROBLEM NO. 1: FIND ALL THE UNIQUE 'WIND SPEED' VALUES IN THE DATA
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
# PROBLEM NO.2 : FIND THE NUMBER OF TIMES WHEN THE 'WEATHER' IS EXACTLY CLEAR
# Using Value Counts
data[data['Weather'] == 'Clear'].value_counts()
# Out:
# Date/Time        Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/11/2012 1:00   -10.7   -17.8             56         17               25.0           101.49     Clear      1
# 6/14/2012 3:00    12.3    5.3              62         13               25.0           101.96     Clear      1
# 6/14/2012 23:00   19.6    5.8              40         6                25.0           102.21     Clear      1
# 6/14/2012 22:00   20.2    6.0              39         9                25.0           102.20     Clear      1
# 6/14/2012 21:00   21.0    6.0              38         11               25.0           102.16     Clear      1
#                                                                                                            ..
# 2/4/2012 19:00   -7.7    -14.0             61         7                25.0           101.97     Clear      1
# ...

# %%
# THROUGH FILTERING
data[data['Weather'] == 'Clear'].filter(['Weather']).count()
# Out:
# Weather    1326
# dtype: int64

# %%
#THROUGH GROUPBY()
data.groupby('Weather').get_group('Clear').count()
data[data['Weather'] == 'Clear'].groupby('Weather').count()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Weather
# Clear         1326    1326              1326       1326             1326
#
#          Visibility_km  Press_kPa
# Weather
# Clear             1326       1326

# %%
# PROBLEM 3: FIND THE NUMBER OF TIMES WHE THE "WIND SPEED WAS EXACTLY 4KM/H"

data[data['Wind Speed_km/h'] == 4].count( ) # 474
data[data['Wind Speed_km/h'] == 4].value_counts() # 474
data[data['Wind Speed_km/h'] == 4].filter(['Wind Speed_km/h']).count() # 474, MUCH BETTER
data[data['Wind Speed_km/h'] == 4].groupby('Wind Speed_km/h').count()
# Out:
#                  Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Wind Speed_km/h
# 4                      474     474               474        474
#
#                  Visibility_km  Press_kPa  Weather
# Wind Speed_km/h
# 4                          474        474      474

# %%
# PROBLEM 4: FIND OUT ALL THE NULL VALUES IN THE DATA
data.isnull().sum() # SHOWS THE NUMBER OF NULL VALUES IN EACH COLUMN
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
# PROBLEM NO. 5: RENAME THE COLUMN NAME "WEATHER" TO "WEATHER CONDITION"

data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True) # RENAME THE COLUMN 'WEATHER' TO 'WEATHER CONDITION'
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# PROBLEM NO. 6: WHAT IS THE MEAN OF THE VISIBILITY?

data['Visibility_km'].mean() # MEAN OF THE VISIBILITY
# Out:
# 27.664446721311478

# %%
# PROBLEM NO. 7: WHAT IS THE STANDARD DEVIATION OF THE PRESSURE AREA?

data['Press_kPa'].std() # STANDARD DEVIATION OF THE PRESSURE AREA
# Out:
# 0.8440047459486474

# %%
# PROBLEM NO. 8: FINDING THE VARIANCE OF THE HUMIDITY
data['Rel Hum_%'].var() # VARIANCE OF THE HUMIDITY
# Out:
# 286.2485501984998

# %%
# PROBLEM NO. 9: FINDING ALL INSTANCES WHERE SNOW IS RECORDED
data.head()
data[data['Weather Condition'].str.contains('Snow')] # SHOWS ALL THE INSTANCES WHERE SNOW IS RECORDED
data[data['Weather Condition'].str.contains('Snow')].filter(['Weather Condition']).count() # SHOWS THE NUMBER OF ALL INSTANCES WHERE SNOW IS RECORDED
# Out:
# Weather Condition    583
# dtype: int64

# %%
# PROBLEM NO. 10: FIND ALL INSTANCES WHEN 'WIND SPEED' IS ABOVE 24 AND 'VISIBILITY' IS 25

data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)].filter(['Wind Speed_km/h', 'Visibility_km']).count()
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
# PROBLEM 11: WHAT IS THE MEAN VALUE OF EACH COLUMN AGAINST EACH 'WEATHER CONDITION'
data.head()
data.groupby('Weather Condition').mean(numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
# PROBLEM 12: WHAT IS THE MINIMUM AND MAXIMUM VALUE OF EACH COLUMN AGAINST EACH WEATHER CONDITION
data.groupby('Weather Condition').agg(['min', 'max'])
# Out:
#                                                 Date/Time                    \
#                                                       min               max
# Weather Condition
# Clear                                      1/11/2012 1:00     9/9/2012 5:00
# Cloudy                                     1/1/2012 17:00    9/9/2012 23:00
# Drizzle                                   1/23/2012 21:00    9/30/2012 3:00
# Drizzle,Fog                               1/23/2012 20:00    9/30/2012 2:00
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00   12/17/2012 9:00
# Drizzle,Snow                             12/17/2012 15:00  12/19/2012 18:00
# Drizzle,Snow,Fog                         12/18/2012 21:00   12/22/2012 3:00
# Fog                                         1/1/2012 0:00    9/22/2012 0:00
# Freezing Drizzle                          1/13/2012 10:00     2/1/2012 5:00
# Freezing Drizzle,Fog                        1/1/2012 2:00   12/10/2012 5:00
# ...

# %%
# PROBLEM 13: SHOW ALL RECORDS WHERE WEATHER CONDITION IS FOG
data[data['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
# PROBLEM # 14: FIND ALL INSTANCES WHEN 'WEATHER IS CLEAR' OR 'VISIBILITY' IS > 40
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
# PROBLEM 15: FIND ALL INSTANCES WHEN:
# a. 'WEATHER IS CLEAR' AND THE RELATIVE HUMIDITY IS GREATER THAN 50
# OR
# B. VISIBILITY IS OVER 40
data[((data['Weather Condition'] == 'Clear') & (data['Rel Hum_%'] > 50)) |  (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
